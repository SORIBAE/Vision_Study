# %%
# !python3 -m pip install torch
# !python3 -m pip install matplotlib
#!python3 -m pip install -U scikit-learn
# !python3 -m pip install scikit-learn
# !python3 -m pip install pandas
# !python3 -m pip install Adam
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# Requirement already satisfied: torch in /home/baesorie/.local/lib/python3.10/site-packages (1.13.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/baesorie/.local/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/baesorie/.local/lib/python3.10/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/baesorie/.local/lib/python3.10/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/baesorie/.local/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: typing-extensions in /home/baesorie/.local/lib/python3.10/site-packages (from torch) (4.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (65.6.3)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.37.1)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# Requirement already satisfied: matplotlib in /home/baesorie/.local/lib/python3.10/site-packages (3.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/baesorie/.local/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/baesorie/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/baesorie/.local/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: numpy>=1.19 in /home/baesorie/.local/lib/python3.10/site-packages (from matplotlib) (1.24.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/baesorie/.local/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/baesorie/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# Requirement already satisfied: scikit-learn in /home/baesorie/.local/lib/python3.10/site-packages (1.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/baesorie/.local/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/baesorie/.local/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/baesorie/.local/lib/python3.10/site-packages (from scikit-learn) (1.24.1)
# Requirement already satisfied: scipy>=1.3.2 in /home/baesorie/.local/lib/python3.10/site-packages (from scikit-learn) (1.10.0)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# Requirement already satisfied: pandas in /home/baesorie/.local/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.21.0 in /home/baesorie/.local/lib/python3.10/site-packages (from pandas) (1.24.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# Requirement already satisfied: Adam in /home/baesorie/.local/lib/python3.10/site-packages (0.0.0.dev0)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)

# %%
# !pip install datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# Collecting datasets
#   Downloading datasets-2.9.0-py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.8/462.8 kB 6.5 MB/s eta 0:00:00a 0:00:01
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 15.7 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.2.0
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 kB 20.5 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.28.1)
# Requirement already satisfied: numpy>=1.17 in /home/baesorie/.local/lib/python3.10/site-packages (from datasets) (1.24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Collecting fsspec[http]>=2021.11.1
#   Downloading fsspec-2023.1.0-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /home/baesorie/.local/lib/python3.10/site-packages (from datasets) (4.64.1)
# Collecting pyarrow>=6.0.0
#   Downloading pyarrow-10.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 16.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas in /home/baesorie/.local/lib/python3.10/site-packages (from datasets) (1.5.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (21.3)
# Collecting dill<0.3.7
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 20.3 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 29.2 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.0/264.0 kB 32.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (22.1.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 19.7 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 28.1 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting filelock
#   Downloading filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/baesorie/.local/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# Installing collected packages: xxhash, pyarrow, multidict, fsspec, frozenlist, filelock, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
#   WARNING: The script plasma_store is installed in '/home/baesorie/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script huggingface-cli is installed in '/home/baesorie/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script datasets-cli is installed in '/home/baesorie/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# Successfully installed aiohttp-3.8.3 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.9.0 dill-0.3.6 filelock-3.9.0 frozenlist-1.3.3 fsspec-2023.1.0 huggingface-hub-0.12.0 multidict-6.0.4 multiprocess-0.70.14 pyarrow-10.0.1 responses-0.18.0 xxhash-3.2.0 yarl-1.8.2
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)

# %%
# !pip list
# Out:
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# Package                  Version
# ------------------------ -----------
# adam                     0.0.0.dev0
# alembic                  1.8.1
# anyio                    3.6.2
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# arrow                    1.2.3
# asttokens                2.2.1
# async-generator          1.10
# attrs                    22.1.0
# Babel                    2.11.0
# backcall                 0.2.0
# beautifulsoup4           4.11.1
# bleach                   5.0.1
# certifi                  2022.9.24
# certipy                  0.1.3
# cffi                     1.15.1
# charset-normalizer       2.1.1
# cifar10                  1.0.0
# comm                     0.1.2
# contourpy                1.0.7
# cryptography             38.0.4
# cycler                   0.11.0
# dataloader               2.0
# debugpy                  1.6.5
# decorator                5.1.1
# defusedxml               0.7.1
# entrypoints              0.4
# executing                1.2.0
# fastjsonschema           2.16.2
# fonttools                4.38.0
# fqdn                     1.5.1
# greenlet                 2.0.1
# gyp                      0.1
# idna                     3.4
# ipykernel                6.20.1
# ipython                  8.8.0
# ipython-genutils         0.2.0
# ipywidgets               8.0.4
# isoduration              20.11.0
# jedi                     0.18.2
# Jinja2                   3.1.2
# joblib                   1.2.0
# json5                    0.9.11
# jsonpointer              2.3
# jsonschema               4.17.3
# jupyter_client           7.4.9
# jupyter_core             5.1.3
# jupyter-events           0.6.3
# jupyter_server           2.1.0
# jupyter_server_terminals 0.4.4
# jupyter-telemetry        0.1.0
# jupyterhub               3.1.0
# jupyterlab               3.5.2
# jupyterlab-pygments      0.2.2
# jupyterlab_server        2.18.0
# jupyterlab-widgets       3.0.5
# keras                    2.11.0
# kiwisolver               1.4.4
# Mako                     1.2.4
# MarkupSafe               2.1.1
# matplotlib               3.6.3
# matplotlib-inline        0.1.6
# mistune                  2.0.4
# munpy                    0.0.0
# nbclassic                0.4.8
# nbclient                 0.7.2
# nbconvert                7.2.7
# nbformat                 5.7.3
# nest-asyncio             1.5.6
# notebook                 6.5.2
# notebook_shim            0.2.2
# numpy                    1.24.1
# nvidia-cublas-cu11       11.10.3.66
# nvidia-cuda-nvrtc-cu11   11.7.99
# nvidia-cuda-runtime-cu11 11.7.99
# nvidia-cudnn-cu11        8.5.0.96
# oauthlib                 3.2.2
# optim                    0.1.0
# packaging                21.3
# pamela                   1.0.0
# pandas                   1.5.2
# pandocfilters            1.5.0
# parso                    0.8.3
# pexpect                  4.8.0
# pickleshare              0.7.5
# Pillow                   9.4.0
# pip                      22.3.1
# platformdirs             2.6.2
# prometheus-client        0.15.0
# prompt-toolkit           3.0.36
# psutil                   5.9.4
# ptyprocess               0.7.0
# pure-eval                0.2.2
# pycparser                2.21
# pycurl                   7.44.1
# Pygments                 2.14.0
# pyOpenSSL                22.1.0
# pyparsing                3.0.9
# pyrsistent               0.19.2
# python-dateutil          2.8.2
# python-json-logger       2.0.4
# pytz                     2022.7.1
# PyYAML                   6.0
# pyzmq                    25.0.0
# requests                 2.28.1
# rfc3339-validator        0.1.4
# rfc3986-validator        0.1.1
# ruamel.yaml              0.17.21
# ruamel.yaml.clib         0.2.7
# scikit-learn             1.1.3
# scipy                    1.10.0
# Send2Trash               1.8.0
# setuptools               65.6.3
# six                      1.16.0
# sklearn                  0.0.post1
# sniffio                  1.3.0
# soupsieve                2.3.2.post1
# SQLAlchemy               1.4.44
# stack-data               0.6.2
# terminado                0.17.1
# threadpoolctl            3.1.0
# tinycss2                 1.2.1
# tomli                    2.0.1
# torch                    1.13.1
# torchvision              0.14.1
# tornado                  6.2
# tqdm                     4.64.1
# traitlets                5.6.0
# typing_extensions        4.4.0
# uri-template             1.2.0
# urllib3                  1.26.13
# wcwidth                  0.2.6
# webcolors                1.12
# webencodings             0.5.1
# websocket-client         1.4.2
# wheel                    0.37.1
# widgetsnbextension       4.0.5
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/home/baesorie/.local/lib/python3.10/site-packages)

# %%
from sklearn.datasets import load_boston
dataset = load_boston()
print(dataset.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
import warnings
warnings.filterwarnings('ignore')

dataset = load_boston() # 데이터셋을 불러옴
print(dataset.keys())   # 데이터셋의 키(요소들의 이름)를 출력
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
import pandas as pd

from sklearn.datasets import load_boston

dataset = load_boston()
dataFrame = pd.DataFrame(dataset["data"]) # ❶ 데이터셋의 데이터 불러오기
dataFrame.columns = dataset["feature_names"] # ❷ 특징의 이름 불러오기
dataFrame["target"] = dataset["target"] # ❸ 데이터 프레임에 정답을 추가

print(dataFrame.head()) # ➍ 데이터프레임을 요약해서 출력
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
import torch
import torch.nn as nn

from torch.optim.adam import Adam


# ❶ 모델 정의
model = nn.Sequential(
   nn.Linear(13, 100),
   nn.ReLU(),
   nn.Linear(100, 1)
)

X = dataFrame.iloc[:, :13].values # ❷ 정답을 제외한 특징을 X에 입력
Y = dataFrame["target"].values    # 데이터프레임의 target의 값을 추출

batch_size = 100
learning_rate = 0.001

# ❸ 가중치를 수정하기 위한 최적화 정의
optim = Adam(model.parameters(), lr=learning_rate)


# 에포크 반복
for epoch in range(200):

   # 배치 반복
   for i in range(len(X)//batch_size):
       start = i*batch_size      # ➍ 배치 크기에 맞게 인덱스를 지정
       end = start + batch_size


       # 파이토치 실수형 텐서로 변환
       x = torch.FloatTensor(X[start:end])
       y = torch.FloatTensor(Y[start:end])

       optim.zero_grad() # ❺ 가중치의 기울기를 0으로 초기화
       preds = model(x)  # ❻ 모델의 예측값 계산
       loss = nn.MSELoss()(preds, y) # ❼ MSE 손실 계산
       loss.backward()
       optim.step()

   if epoch % 20 == 0:
       print(f"epoch{epoch} loss:{loss.item()}")
# Out:
# epoch0 loss:1745.33642578125
# epoch20 loss:42.21973419189453
# epoch40 loss:38.67533874511719
# epoch60 loss:38.15384292602539
# epoch80 loss:37.959259033203125
# epoch100 loss:37.714698791503906
# epoch120 loss:37.657413482666016
# epoch140 loss:37.59111404418945
# epoch160 loss:37.51259231567383
# epoch180 loss:37.428855895996094

# %%
prediction = model(torch.FloatTensor(X[0, :13]))
real = Y[0]
print(f"prediction:{prediction.item()} real:{real}")
# Out:
# prediction:25.038990020751953 real:24.0
